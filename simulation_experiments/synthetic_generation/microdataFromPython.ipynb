# %%
import get_microdata as gm
import pandas as pd
import numpy as np
import os
import random

naics6df = pd.read_csv(os.getcwd()+"/Get4and6NAICS_R_output/DataNAICS6.csv")
random.seed(1)
tempdf = gm.make_syn_microdata(naics6df,numchunk=35,outfoldername=os.getcwd()+"/PythonMicrodataSubsets/")
#tempdf.to_csv(os.getcwd()+'SynMicrodata'+str(counter)+".csv")
#counter=0
#chunk_size=round(len(naics6df['state'])/4)
#print(chunk_size)
#splitdf = [naics6df[i:i+chunk_size] for i in range(0,len(naics6df),chunk_size)]
#print(splitdf[0].head())
#for subdata in splitdf:
#    counter=counter+1
#    tempdf = gm.make_syn_microdata(subdata)
#    tempdf.to_csv('SynMicrodata'+str(counter)+".csv")
#microdata = gm.make_syn_microdata(naics6)
#print(microdata.head())
# Out:
# starting make_syn_microdata: chunk size=15859
# split data frame checkpoint
# Data set 1 took 55.30006551742554  to process.
# Data set 2 took 686.3162605762482  to process.
# Data set 3 took 41.7869598865509  to process.
# Data set 4 took 72.17793440818787  to process.
# Data set 5 took 35.3606173992157  to process.
# Data set 6 took 114.16349244117737  to process.
# Data set 7 took 31.716799020767212  to process.
# Data set 8 took 31.164270877838135  to process.
# Data set 9 took 31.87554621696472  to process.
# Data set 10 took 39.55562090873718  to process.
# Data set 11 took 37.73030924797058  to process.
# Data set 12 took 30.813915252685547  to process.
# Data set 13 took 65.768230676651  to process.
# Data set 14 took 36.86703300476074  to process.
# Data set 15 took 123.73058605194092  to process.
# Data set 16 took 33.018311738967896  to process.
# Data set 17 took 34.009711503982544  to process.
# Data set 18 took 33.76402449607849  to process.
# ...

# %% [markdown]
# import psutil
# import platform
#
#
# def get_size(bytes, suffix="B"):
#     """
#     Scale bytes to its proper format
#     e.g:
#         1253656 => '1.20MB'
#         1253656678 => '1.17GB'
#     """
#     factor = 1024
#     for unit in ["", "K", "M", "G", "T", "P"]:
#         if bytes < factor:
#             return f"{bytes:.2f}{unit}{suffix}"
#         bytes /= factor
#
# print("="*40, "System Information", "="*40)
# uname = platform.uname()
# print(f"System: {uname.system}")
# print(f"Node Name: {uname.node}")
# print(f"Release: {uname.release}")
# print(f"Version: {uname.version}")
# print(f"Machine: {uname.machine}")
# print(f"Processor: {uname.processor}")
#
# # let's print CPU information
# print("="*40, "CPU Info", "="*40)
# # number of cores
# print("Physical cores:", psutil.cpu_count(logical=False))
# print("Total cores:", psutil.cpu_count(logical=True))
# # CPU frequencies
# cpufreq = psutil.cpu_freq()
# print(f"Max Frequency: {cpufreq.max:.2f}Mhz")
# print(f"Min Frequency: {cpufreq.min:.2f}Mhz")
# print(f"Current Frequency: {cpufreq.current:.2f}Mhz")
# # CPU usage
# print("CPU Usage Per Core:")
# for i, percentage in enumerate(psutil.cpu_percent(percpu=True, interval=1)):
#     print(f"Core {i}: {percentage}%")
# print(f"Total CPU Usage: {psutil.cpu_percent()}%")
#
# # Memory Information
# print("="*40, "Memory Information", "="*40)
# # get the memory details
# svmem = psutil.virtual_memory()
# print(f"Total: {get_size(svmem.total)}")
# print(f"Available: {get_size(svmem.available)}")
# print(f"Used: {get_size(svmem.used)}")
# print(f"Percentage: {svmem.percent}%")
# print("="*20, "SWAP", "="*20)
# # get the swap memory details (if exists)
# swap = psutil.swap_memory()
# print(f"Total: {get_size(swap.total)}")
# print(f"Free: {get_size(swap.free)}")
# print(f"Used: {get_size(swap.used)}")
# print(f"Percentage: {swap.percent}%")
#
# #Disk Information
# print("="*40, "Disk Information", "="*40)
# print("Partitions and Usage:")
# # get all disk partitions
# partitions = psutil.disk_partitions()
# for partition in partitions:
#     print(f"=== Device: {partition.device} ===")
#     print(f"  Mountpoint: {partition.mountpoint}")
#     print(f"  File system type: {partition.fstype}")
#     try:
#         partition_usage = psutil.disk_usage(partition.mountpoint)
#     except PermissionError:
#         # this can be catched due to the disk that
#         # isn't ready
#         continue
#     print(f"  Total Size: {get_size(partition_usage.total)}")
#     print(f"  Used: {get_size(partition_usage.used)}")
#     print(f"  Free: {get_size(partition_usage.free)}")
#     print(f"  Percentage: {partition_usage.percent}%")
# # get IO statistics since boot
# disk_io = psutil.disk_io_counters()
# print(f"Total read: {get_size(disk_io.read_bytes)}")
# print(f"Total write: {get_size(disk_io.write_bytes)}")
#
# # Network information
# print("="*40, "Network Information", "="*40)
# # get all network interfaces (virtual and physical)
# if_addrs = psutil.net_if_addrs()
# for interface_name, interface_addresses in if_addrs.items():
#     for address in interface_addresses:
#         print(f"=== Interface: {interface_name} ===")
#         if str(address.family) == 'AddressFamily.AF_INET':
#             print(f"  IP Address: {address.address}")
#             print(f"  Netmask: {address.netmask}")
#             print(f"  Broadcast IP: {address.broadcast}")
#         elif str(address.family) == 'AddressFamily.AF_PACKET':
#             print(f"  MAC Address: {address.address}")
#             print(f"  Netmask: {address.netmask}")
#             print(f"  Broadcast MAC: {address.broadcast}")
# # get IO statistics since boot
# net_io = psutil.net_io_counters()
# print(f"Total Bytes Sent: {get_size(net_io.bytes_sent)}")
# print(f"Total Bytes Received: {get_size(net_io.bytes_recv)}")

# %%
# ======================================== System Information ========================================
# System: Linux
# Node Name: p-bc-5005
# Release: 4.18.0-513.18.1.el8_9.x86_64
# Version: #1 SMP Thu Feb 1 03:51:05 EST 2024
# Machine: x86_64
# Processor: x86_64
# ======================================== CPU Info ========================================
# Physical cores: 24
# Total cores: 24
# Max Frequency: 2900.00Mhz
# Min Frequency: 1200.00Mhz
# Current Frequency: 2510.10Mhz
# CPU Usage Per Core:
# Core 0: 100.0%
# Core 1: 2.0%
# Core 2: 100.0%
# Core 3: 1.0%
# Core 4: 100.0%
# Core 5: 100.0%
# Core 6: 49.5%
# Core 7: 85.0%
# Core 8: 55.0%
# Core 9: 2.0%
# Core 10: 1.0%
# Core 11: 1.0%
# Core 12: 2.0%
# Core 13: 1.0%
# Core 14: 0.0%
# Core 15: 0.0%
# Core 16: 2.0%
# Core 17: 0.0%
# Core 18: 3.0%
# Core 19: 1.0%
# Core 20: 2.0%
# Core 21: 100.0%
# Core 22: 1.0%
# Core 23: 100.0%
# Total CPU Usage: 28.3%
# ======================================== Memory Information ========================================
# Total: 125.78GB
# Available: 114.99GB
# Used: 4.97GB
# Percentage: 8.6%
# ==================== SWAP ====================
# Total: 0.00B
# Free: 0.00B
# Used: 0.00B
# Percentage: 0.0%
# ======================================== Disk Information ========================================
# Partitions and Usage:
# === Device: /dev/sda1 ===
#   Mountpoint: /var/log
#   File system type: xfs
#   Total Size: 93.09GB
#   Used: 1.01GB
#   Free: 92.07GB
#   Percentage: 1.1%
# === Device: /dev/sda3 ===
#   Mountpoint: /var/tmp
#   File system type: xfs
#   Total Size: 931.09GB
#   Used: 6.52GB
#   Free: 924.57GB
#   Percentage: 0.7%
# === Device: /dev/sda3 ===
#   Mountpoint: /var/tmp/11748413
#   File system type: xfs
#   Total Size: 931.09GB
#   Used: 6.52GB
#   Free: 924.57GB
#   Percentage: 0.7%
# === Device: /dev/sda3 ===
#   Mountpoint: /var/tmp/11748417
#   File system type: xfs
#   Total Size: 931.09GB
#   Used: 6.52GB
#   Free: 924.57GB
#   Percentage: 0.7%
# === Device: /dev/sda3 ===
#   Mountpoint: /var/tmp/11748414
#   File system type: xfs
#   Total Size: 931.09GB
#   Used: 6.52GB
#   Free: 924.57GB
#   Percentage: 0.7%
# === Device: /dev/sda3 ===
#   Mountpoint: /var/tmp/11748416
#   File system type: xfs
#   Total Size: 931.09GB
#   Used: 6.52GB
#   Free: 924.57GB
#   Percentage: 0.7%
# === Device: /dev/sda3 ===
#   Mountpoint: /var/tmp/11802717
#   File system type: xfs
#   Total Size: 931.09GB
#   Used: 6.52GB
#   Free: 924.57GB
#   Percentage: 0.7%
# === Device: /dev/sda3 ===
#   Mountpoint: /var/tmp/11830342
#   File system type: xfs
#   Total Size: 931.09GB
#   Used: 6.52GB
#   Free: 924.57GB
#   Percentage: 0.7%
# === Device: /dev/sda2 ===
#   Mountpoint: /tmp
#   File system type: xfs
#   Total Size: 931.09GB
#   Used: 6.52GB
#   Free: 924.57GB
#   Percentage: 0.7%
# === Device: /dev/sda3 ===
#   Mountpoint: /tmp
#   File system type: xfs
#   Total Size: 931.09GB
#   Used: 6.52GB
#   Free: 924.57GB
#   Percentage: 0.7%
# Total read: 40.96GB
# Total write: 2.50TB
# ======================================== Network Information ========================================
# === Interface: lo ===
#   IP Address: 127.0.0.1
#   Netmask: 255.0.0.0
#   Broadcast IP: None
# === Interface: lo ===
# === Interface: lo ===
#   MAC Address: 00:00:00:00:00:00
#   Netmask: None
#   Broadcast MAC: None
# === Interface: eno1 ===
#   IP Address: 10.6.8.15
#   Netmask: 255.255.240.0
#   Broadcast IP: 10.6.15.255
# === Interface: eno1 ===
# === Interface: eno1 ===
#   MAC Address: 14:9e:cf:e7:a7:95
#   Netmask: None
#   Broadcast MAC: ff:ff:ff:ff:ff:ff
# === Interface: eno2 ===
#   MAC Address: 14:9e:cf:e7:a7:97
#   Netmask: None
#   Broadcast MAC: ff:ff:ff:ff:ff:ff
# Total Bytes Sent: 13.33TB
# Total Bytes Received: 193.07TB
